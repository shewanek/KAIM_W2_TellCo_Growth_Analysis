# %% [markdown]
# # Experience Analytics
#
# The objective is to conduct a comprehensive user experience analysis by focusing on key network parameters and device characteristics, ultimately helping to optimize products and services in the telecommunication industry.

# %%
# Import necessary libraries and modules
import os
import sys
import warnings
import pandas as pd

# Add parent directory to path to import local modules
sys.path.insert(0, os.path.dirname(os.getcwd()))
from scripts.exp_analysis import TelecomAnalyzer


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Load the data
df = pd.read_csv('../data/clean_proccessed_data.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#       Bearer Id            Start              End   Dur. (s)  MSISDN/Number  \
# 0  1.311448e+19   4/4/2019 12:01  4/25/2019 14:35  1823652.0   3.366496e+10
# 1  1.311448e+19   4/9/2019 13:04   4/25/2019 8:15  1365104.0   3.368185e+10
# 2  1.311448e+19   4/9/2019 17:42  4/25/2019 11:58  1361762.0   3.376063e+10
# 3  1.311448e+19   4/10/2019 0:31   4/25/2019 7:36  1321509.0   3.375034e+10
# 4  1.311448e+19  4/12/2019 20:10  4/25/2019 10:40  1089009.0   3.369980e+10
#
#            IMSI          IMEI  Avg Bearer TP DL (kbps)  \
# 0  2.082014e+14  3.552121e+13                     23.0
# 1  2.082019e+14  3.579401e+13                     16.0
# 2  2.082003e+14  3.528151e+13                      6.0
# 3  2.082014e+14  3.535661e+13                     44.0
# 4  2.082014e+14  3.540701e+13                      6.0
#
#    Avg Bearer TP UL (kbps)  Avg RTT DL (ms)  ...  Other DL (Bytes)  \
# 0                     44.0        42.000000  ...       171744450.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Bearer Id                       150001 non-null  float64
#  1   Start                           150001 non-null  object
#  2   End                             150001 non-null  object
#  3   Dur. (s)                        150001 non-null  float64
#  4   MSISDN/Number                   150001 non-null  float64
#  5   IMSI                            150001 non-null  float64
#  6   IMEI                            150001 non-null  float64
#  7   Avg Bearer TP DL (kbps)         150001 non-null  float64
#  8   Avg Bearer TP UL (kbps)         150001 non-null  float64
#  9   Avg RTT DL (ms)                 150001 non-null  float64
#  10  Avg RTT UL (ms)                 150001 non-null  float64
# ...

# %%
exp_anly = TelecomAnalyzer(df)

# %%
exp_anly.analyze_distributions()
# Out:
# Top 15 Handsets by Average Throughput:
#                           Handset Type  Avg Bearer TP DL (kbps)
#                New-Bund Technol. Mix 2            104669.000000
#                                 Lg G6+             97747.000000
#                       Huawei B715S-23C             92075.692308
#                         Huawei Y9 2019             90557.000000
#            Spa Condor Elect. Allure M2             83294.500000
#              Zyxel Communicat. Sbg3600             82818.000000
#             Xiaomi Communica. M1902F1G             81646.666667
#                            Huawei Pele             76474.000000
#             Shenzhen Leagoo. Leagoo S8             74086.000000
#             Spa Condor Elect. Plume L2             73997.000000
# Doke Communicati. Blackview Bv6800 Pro             72595.000000
#                 Xiaomi Communica. Mi 6             72390.500000
#          A-Link Telecom I. Cubot Power             69126.000000
# ...

# %% [markdown]
# ### Analysis of top 15 handsets by average throughput:
#
# - **New-Bund Technology Mix 2** leads with an impressive 104.7 Mbps download speed, showcasing its superior network performance.
# - High-end phones like **LG G6+** and **Huawei Y9 2019** show strong performance with download speeds close to 90+ Mbps.
# - The list includes a mix of established brands (Huawei, LG, Xiaomi) and emerging manufacturers, indicating a diverse market presence.
# - Throughput ranges from 65-104 Mbps, showing significant performance variation among different handsets.
# - Notable presence of specialized devices like **Huawei B715S router** and **Zyxel modem**, which are designed for high performance.
# - Mid-range phones like **Oppo Cph1723** and **Huawei Aum-Al00** still achieve respectable speeds above 65 Mbps.
# - Several rugged/specialized phones present (e.g., **Blackview BV6800 Pro**, **Leagoo S8**), indicating their capability to handle high throughput.
# - Chinese manufacturers dominate the list, reflecting their growing influence and market share in the telecommunication industry.
# - Data suggests that modern 4G/LTE networks can deliver strong real-world performance across various device types.
# - Even lower-ranked devices provide adequate speeds for most mobile applications, ensuring a good user experience across the board.

# %% [markdown]
# ### Analysis of top 15 handsets by average throughput:
#  - New-Bund Technology Mix 2 leads with impressive 104.7 Mbps download speed
#  - High-end phones like LG G6+ and Huawei Y9 2019 show strong performance (90+ Mbps)
#  - Mix of established brands (Huawei, LG, Xiaomi) and emerging manufacturers
#  - Throughput range from 65-104 Mbps shows significant performance variation
#  - Notable presence of specialized devices like Huawei B715S router and Zyxel modem
#  - Mid-range phones like Oppo and Huawei models still achieve respectable 65+ Mbps
#  - Several rugged/specialized phones present (Blackview BV6800 Pro, Leagoo S8)
#  - Chinese manufacturers dominate the list, showing their growing market presence
#  - Data suggests modern 4G/LTE networks can deliver strong real-world performance
#  - Even lower-ranked devices provide adequate speeds for most mobile applications

# %% [markdown]
# ### Key insights from handsets by average TCP retransmission volume in bytes:
#
# 1. The 'Lg Lg-H635' handset has the highest TCP downlink retransmission volume, significantly higher than the others, indicating potential issues with network stability or handset performance.
# 2. Handsets from various manufacturers such as LG, Huawei, Asustek, and Samsung are present in the top 15, suggesting that TCP retransmission issues are not isolated to a single brand.
# 3. The presence of both smartphones and other devices like tablets and communication devices (e.g., Huawei B528S-23A, Zyxel Communicat. Sbg3600) indicates that TCP retransmission is a broader issue affecting multiple types of devices.
# 4. The significant difference in retransmission volumes between the top handset and the 15th handset suggests a wide variance in network performance or device handling of TCP retransmissions.
#
# Understanding these insights can help in identifying and addressing network performance issues, improving device firmware, or optimizing network configurations to reduce TCP retransmissions.

# %%
exp_anly.run_kmeans_clustering()
# Out:
#                avg_tcp_retrans   avg_rtt  avg_throughput  \
# MSISDN/Number
# 3.360100e+10      4.851375e-03  0.000475        0.000140
# 3.360100e+10      4.851375e-03  0.000310        0.000182
# 3.360100e+10      4.851375e-03  0.001133        0.000182
# 3.360101e+10      2.480483e-07  0.000712        0.000771
# 3.360101e+10      3.515518e-03  0.000588        0.076376
# ...                        ...       ...             ...
# 3.379000e+10      4.851375e-03  0.000351        0.000257
# 4.188282e+10      3.858343e-03  0.002977        0.057624
# 3.197021e+12      4.851375e-03  0.001133        0.000004
# 3.370000e+14      4.851375e-03  0.001133        0.000042
# 8.823971e+14      4.851375e-03  0.001133        0.000008
#
#                                    Handset Type  cluster
# MSISDN/Number
# 3.360100e+10     Huawei P20 Lite Huawei Nova 3E        0
# 3.360100e+10             Apple iPhone 7 (A1778)        0
# 3.360100e+10                          undefined        0
# ...

# %%
exp_anly.describe_clusters()
# Out:
# Cluster Descriptions:
#          avg_tcp_retrans                       avg_rtt                      \
#                     min       max      mean       min       max      mean
# cluster
# 0          0.000000e+00  0.636964  0.003962  0.000000  1.000000  0.001328
# 1          6.760714e-09  0.999667  0.017931  0.000165  0.029807  0.000701
# 2          7.693227e-09  1.000000  0.004021  0.000155  0.085563  0.000935
#
#         avg_throughput                                 Handset Type
#                    min       max      mean                 <lambda>
# cluster
# 0             0.000000  0.063046  0.007358  Apple iPhone 6S (A1688)
# 1             0.134654  1.000000  0.288586         Huawei B528S-23A
# 2             0.063054  0.204570  0.118596         Huawei B528S-23A
#         avg_tcp_retrans                       avg_rtt                      \
#                     min       max      mean       min       max      mean
# cluster
# ...

# %% [markdown]
# ### Key Insights from Cluster Descriptions:
#
# 1. **Cluster 0**:
#     - **Average TCP Retransmission**: The mean value is very low (0.003962), indicating minimal retransmission issues. The maximum value is 0.636964, suggesting that some devices in this cluster experience higher retransmissions.
#     - **Average RTT**: The mean RTT is 0.001328, with a maximum of 1.000000, indicating generally low latency but with some outliers.
#     - **Average Throughput**: The mean throughput is 0.007358, with a maximum of 0.063046, indicating lower throughput performance.
#     - **Handset Type**: Predominantly consists of Apple iPhone 6S (A1688), suggesting that this model generally experiences low retransmissions and latency but also lower throughput.
#
# 2. **Cluster 1**:
#     - **Average TCP Retransmission**: The mean value is 0.017931, higher than Cluster 0, indicating more retransmission issues. The maximum value is close to 1, suggesting significant retransmission problems for some devices.
#     - **Average RTT**: The mean RTT is 0.000701, with a maximum of 0.029807, indicating low latency overall.
#     - **Average Throughput**: The mean throughput is 0.288586, with a maximum of 1.000000, indicating high throughput performance.
#     - **Handset Type**: Consists of Huawei B528S-23A, indicating that this model generally experiences higher throughput but also higher retransmission issues.
#
# 3. **Cluster 2**:
#     - **Average TCP Retransmission**: The mean value is 0.004021, slightly higher than Cluster 0 but lower than Cluster 1, indicating moderate retransmission issues.
#     - **Average RTT**: The mean RTT is 0.000935, with a maximum of 0.085563, indicating low latency with some outliers.
#     - **Average Throughput**: The mean throughput is 0.118596, with a maximum of 0.204570, indicating moderate throughput performance.
#     - **Handset Type**: Also consists of Huawei B528S-23A, suggesting that this model has a consistent performance pattern across different clusters.
#
# Overall, the analysis shows that the Huawei B528S-23A model appears in multiple clusters with varying performance metrics, indicating its versatility. The Apple iPhone 6S (A1688) shows lower throughput but minimal retransmission and latency issues.
